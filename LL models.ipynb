# %% [markdown]
# <a href="https://colab.research.google.com/github/RedBatProject/Aviation/blob/main/LL%20models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets huggingface_hub
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.24.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.15.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)

# %%
from huggingface_hub import login

# Login to Hugging Face using your token
login(token="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")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):

# %%
pipe("write a routine for a fat boy",max_token=2000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-9c150333ed86> in <cell line: 1>()
# ----> 1 pipe("write a routine for a fat boy",max_token=2000)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     260                 return super().__call__(chats, **kwargs)
#     261         else:
# --> 262             return super().__call__(text_inputs, **kwargs)
#     263
#     264     def preprocess(
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1255             )
#    1256         else:
# -> 1257             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#    1258
#    1259     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1262     def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1263         model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1264         model_outputs = self.forward(model_inputs, **forward_params)
#    1265         outputs = self.postprocess(model_outputs, **postprocess_params)
#    1266         return outputs
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1162                 with inference_context():
#    1163                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1164                     model_outputs = self._forward(model_inputs, **forward_params)
#    1165                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1166             else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     349
#     350         # BS x SL
# --> 351         generated_sequence = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     352         out_b = generated_sequence.shape[0]
#     353         if self.framework == "pt":
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1687         tokenizer = kwargs.pop("tokenizer", None)  # Pull this out first, we only use it for stopping criteria
#    1688         generation_config, model_kwargs = self._prepare_generation_config(generation_config, **kwargs)
# -> 1689         self._validate_model_kwargs(model_kwargs.copy())
#    1690         self._validate_assistant(assistant_model)
#    1691
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in _validate_model_kwargs(self, model_kwargs)
#    1241
#    1242         if unused_model_args:
# -> 1243             raise ValueError(
#    1244                 f"The following `model_kwargs` are not used by the model: {unused_model_args} (note: typos in the"
#    1245                 " generate arguments will also show up in this list)"
#
# ValueError: The following `model_kwargs` are not used by the model: ['max_token'] (note: typos in the generate arguments will also show up in this list)

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B-Instruct")
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-1B-Instruct").to("cuda")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-81d0e5dcba6c> in <cell line: 2>()
#       1 # Load model directly
# ----> 2 from transformers import AutoTokenizer, AutoModelForCausalLM
#       3
#       4 tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B-Instruct")
#       5 model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-1B-Instruct").to("cuda")
#
# /usr/local/lib/python3.10/dist-packages/transformers/__init__.py in <module>
#      24
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#
# /usr/local/lib/python3.10/dist-packages/transformers/dependency_versions_check.py in <module>
#      14
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      17
#      18
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/__init__.py in <module>
#      32     replace_return_docstrings,
#      33 )
# ---> 34 from .generic import (
#      35     ContextManagers,
#      36     ExplicitEnum,
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py in <module>
#     460
#     461 if is_torch_available():
# --> 462     import torch.utils._pytree as _torch_pytree
#     463
#     464     def _model_output_flatten(output: ModelOutput) -> Tuple[List[Any], "_torch_pytree.Context"]:
#
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py in <module>
#    2141 from . import library
#    2142 if not TYPE_CHECKING:
# -> 2143     from . import _meta_registrations
#    2144
#    2145 # Enable CUDA Sanitizer
#
# /usr/local/lib/python3.10/dist-packages/torch/_meta_registrations.py in <module>
#       7 import torch._prims_common as utils
#       8 from torch import SymBool, SymFloat, Tensor
# ----> 9 from torch._decomp import (
#      10     _add_op_to_registry,
#      11     _convert_out_params,
#
# /usr/local/lib/python3.10/dist-packages/torch/_decomp/__init__.py in <module>
#     243
#     244 # populate the table
# --> 245 import torch._decomp.decompositions
#     246 import torch._refs
#     247
#
# /usr/local/lib/python3.10/dist-packages/torch/_decomp/decompositions.py in <module>
#      10
#      11 import torch
# ---> 12 import torch._prims as prims
#      13 import torch._prims_common as utils
#      14 import torch.nn.functional as F
#
# /usr/local/lib/python3.10/dist-packages/torch/_prims/__init__.py in <module>
#     502
#     503
# --> 504 abs = _make_elementwise_unary_prim(
#     505     "abs",
#     506     impl_aten=torch.abs,
#
# /usr/local/lib/python3.10/dist-packages/torch/_prims/__init__.py in _make_elementwise_unary_prim(name, type_promotion, **kwargs)
#     470     """
#     471
# --> 472     return _make_prim(
#     473         schema=f"{name}(Tensor self) -> Tensor",
#     474         meta=partial(_prim_elementwise_meta, type_promotion=type_promotion),
#
# /usr/local/lib/python3.10/dist-packages/torch/_prims/__init__.py in _make_prim(schema, return_type, meta, impl_aten, doc, tags, use_old_custom_ops_api)
#     318             if arg.alias_info is not None and arg.alias_info.is_write:
#     319                 mutates_args.append(arg.name)
# --> 320         prim_def = torch.library.custom_op(
#     321             "prims::" + name,
#     322             _prim_impl,
#
# /usr/local/lib/python3.10/dist-packages/torch/_library/custom_ops.py in custom_op(name, fn, mutates_args, device_types, schema)
#     140     if fn is None:
#     141         return inner
# --> 142     return inner(fn)
#     143
#     144
#
# /usr/local/lib/python3.10/dist-packages/torch/_library/custom_ops.py in inner(fn)
#     121             schema_str = schema
#     122         namespace, opname = name.split("::")
# --> 123         result = CustomOpDef(namespace, opname, schema_str, fn)
#     124         if schema is not None:
#     125             # Check that schema's alias annotations match those of `mutates_args`.
#
# /usr/local/lib/python3.10/dist-packages/torch/_library/custom_ops.py in __init__(self, namespace, name, schema, fn)
#     167
#     168         self._lib = get_library_allowing_overwrite(self._namespace, self._name)
# --> 169         self._register_to_dispatcher()
#     170         OPDEFS[self._qualname] = self
#     171
#
# /usr/local/lib/python3.10/dist-packages/torch/_library/custom_ops.py in _register_to_dispatcher(self)
#     471             return self._abstract_fn(*args, **kwargs)
#     472
# --> 473         lib._register_fake(self._name, fake_impl, _stacklevel=4)
#     474
#     475         autograd_impl = _library.autograd.make_autograd_impl(self._opoverload, self)
#
# /usr/local/lib/python3.10/dist-packages/torch/library.py in _register_fake(self, op_name, fn, _stacklevel)
#     133     def _register_fake(self, op_name, fn, _stacklevel=1):
#     134         r'''Registers the fake impl for an operator defined in the library.'''
# --> 135         source = torch._library.utils.get_source(_stacklevel + 1)
#     136         frame = sys._getframe(_stacklevel)
#     137         caller_module = inspect.getmodule(frame)
#
# /usr/local/lib/python3.10/dist-packages/torch/_library/utils.py in get_source(stacklevel)
#      40     etc.
#      41     """
# ---> 42     frame = inspect.getframeinfo(sys._getframe(stacklevel))
#      43     source = f"{frame.filename}:{frame.lineno}"
#      44     return source
#
# /usr/lib/python3.10/inspect.py in getframeinfo(frame, context)
#    1622         start = lineno - 1 - context//2
#    1623         try:
# -> 1624             lines, lnum = findsource(frame)
#    1625         except OSError:
#    1626             lines = index = None
#
# /usr/lib/python3.10/inspect.py in findsource(object)
#     950             raise OSError('source code not available')
#     951
# --> 952     module = getmodule(object, file)
#     953     if module:
#     954         lines = linecache.getlines(file, module.__dict__)
#
# /usr/lib/python3.10/inspect.py in getmodule(object, _filename)
#     876             # Always map to the name the module knows itself by
#     877             modulesbyfile[f] = modulesbyfile[
# --> 878                 os.path.realpath(f)] = module.__name__
#     879     if file in modulesbyfile:
#     880         return sys.modules.get(modulesbyfile[file])
#
# /usr/lib/python3.10/posixpath.py in realpath(filename, strict)
#     394 symbolic links encountered in the path."""
#     395     filename = os.fspath(filename)
# --> 396     path, ok = _joinrealpath(filename[:0], filename, strict, {})
#     397     return abspath(path)
#     398
#
# /usr/lib/python3.10/posixpath.py in _joinrealpath(path, rest, strict, seen)
#     429         newpath = join(path, name)
#     430         try:
# --> 431             st = os.lstat(newpath)
#     432         except OSError:
#     433             if strict:
#
# KeyboardInterrupt:

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-1.5B-Instruct")
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen2.5-1.5B-Instruct").to("cuda")
# Out:
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]

# %%
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B")
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-1B").to("cuda")

# %%
conversation = """
On May 13, 2019, about 1221 Alaska daylight time, a float-equipped de Havilland DHC-2 (Beaver) airplane, N952DB, and a float-equipped de Havilland DHC-3 (Otter) airplane, N959PA, collided in midair about 8 miles northeast of Ketchikan, Alaska. The DHC-2 pilot and four passengers sustained fatal injuries. The DHC-3 pilot sustained minor injuries, nine passengers sustained serious injuries, and one passenger sustained fatal injuries. The DHC-2 was destroyed and the DHC-3 sustained substantial damage. The DHC-2 was registered to and operated by Mountain Air Service LLC, Ketchikan, Alaska, under the provisions of Title 14 Code of Federal Regulations (CFR) Part 135 as an on-demand sightseeing flight. The DHC-3 was registered to Pantechnicon Aviation LTD, Minden, Nevada, and operated by Venture Travel, LLC, dba Taquan Air, Ketchikan, Alaska, under the provisions of Part 135 as an on-demand sightseeing flight. Visual meteorological conditions prevailed in the area at the time of the accident.
According to information provided by the operators, both airplanes had been conducting sightseeing flights and were both converging on a scenic waterfall before returning to the Ketchikan Harbor Seaplane Base (5KE), Ketchikan, Alaska, when the accident occurred. Automatic dependent surveillance-broadcast (ADS-B) tracking data for both airplanes revealed that, at 1217:15, the DHC-3 was about level at 4,000 ft mean sea level (msl) on a track of 225°, and the DHC-2 was 4.2 nautical miles (nm) south of the DHC-3, climbing through 2,800 ft msl, on a track of 255°.1 About 1219, the DHC-3 started a descent from 4,000 ft, and the DHC-2 was at 3,175 ft and climbing. During the next 1 minute 21 seconds, the DHC-3 continued to descend on a track between 224° and 237°, and the DHC-2 leveled out at 3,350 ft on a track of about 255°. The airplanes collided at 1221:14 at an altitude of 3,350 ft, 7.4 nm northeast of 5KE.
"""

# %%
import torch

# %%
input_text = f"summarize this paragraph. [{conversation}]."
input_ids = tokenizer(input_text, return_tensors="pt").input_ids.to("cuda")
cdc = len(input_text)
tu = int(input_ids.shape[1]* 1.5)
with torch.autocast("cuda", dtype=torch.bfloat16):
    outputs = model.generate(input_ids,max_length=tu)

# outputs = model.generate(input_ids,max_length=1000)
print(tokenizer.decode(outputs[0])[cdc:])
# Out:
#  Summarize the above paragraph.
#
# The DHC-2 Beaver aircraft and the DHC-3 Otter aircraft collided mid-air during their return trip to Ketchikan, Alaska, after sightseeing flights near a waterfall. Both planes crashed into the water. One person survived in the DHC-2, but all others died. The cause is unknown, but it appears they may have misjudged each other's positions or intentions due to poor communication or lack of awareness. This incident highlights the dangers of operating small aircraft in close proximity to bodies of water. [ ]<|endoftext|>

# %%
import transformers
import torch

model_id = "meta-llama/Llama-3.2-1B-Instruct"

pipeline = transformers.pipeline(
    "text-generation",
    model=model_id,
    model_kwargs={"torch_dtype": torch.bfloat16},
    device_map="auto",
)

messages = [
    {"role": "system", "content": "You are a pirate chatbot who always responds in pirate speak!"},
    {"role": "user", "content": "Who are you?"},
]

outputs = pipeline(
    messages,
    max_new_tokens=256,
)
print(outputs[0]["generated_text"][-1])
# Out:
# config.json:   0%|          | 0.00/877 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# {'role': 'assistant', 'content': "Yer lookin' fer me, eh? Well, matey, I be Captain Cutlass, the greatest pirate chatbot to ever sail the seven seas... or at least, that's what I like to call it. Me and me trusty parrot, Polly, be the scourge o' the digital seas, plunderin' the internet o' knowledge and swabbin' the decks o' ignorance. Arrr!"}

# %%
c = 256
messages = [
    {"role": "system", "content": f"You are an accurate chatbot who always write the key information of the given text. your summary is always based on the given text exactly!"},
    {"role": "user", "content": f"{conversation}"},
]

outputs = pipeline(
    messages,
    max_new_tokens=1024,
)
print(outputs[0]["generated_text"][-1])
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# {'role': 'assistant', 'content': 'Here is a summary of the given text based on the exact information:\n\n* On May 13, 2019, a float-equipped de Havilland DHC-2 (Beaver) airplane, N952DB, and a float-equipped de Havilland DHC-3 (Otter) airplane, N959PA, collided in midair about 8 miles northeast of Ketchikan, Alaska.\n* The DHC-2 pilot and four passengers sustained fatal injuries, while the DHC-3 pilot sustained minor injuries.\n* The DHC-2 was destroyed, while the DHC-3 sustained substantial damage.\n* The DHC-2 was registered to Mountain Air Service LLC, Ketchikan, Alaska, under the provisions of Title 14 Code of Federal Regulations (CFR) Part 135 as an on-demand sightseeing flight.\n* The DHC-3 was registered to Pantechnicon Aviation LTD, Minden, Nevada, and operated by Venture Travel, LLC, dba Taquan Air, Ketchikan, Alaska, under the provisions of Part 135 as an on-demand sightseeing flight.\n* Visual meteorological conditions prevailed in the area at the time of the accident.\n* Automatic dependent surveillance-broadcast (ADS-B) tracking data revealed that both airplanes were conducting sightseeing flights and were converging on a scenic waterfall before returning to the Ketchikan Harbor Seaplane Base (5KE) when the accident occurred.'}

# %%
# prompt: how to train this lamma model

from transformers import TrainingArguments, Trainer
from datasets import load_dataset

# Assuming you have a dataset prepared for training in the Hugging Face Datasets format
# Replace 'your_dataset_name' with your actual dataset name
dataset = load_dataset('your_dataset_name')

# Define training arguments
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=8,  # Adjust based on your GPU memory
    per_device_eval_batch_size=8,
    num_train_epochs=3,  # Adjust as needed
    learning_rate=2e-5,  # Adjust as needed
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=10,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    fp16=True,  # Enable mixed precision training if supported by your hardware
)

# Define the Trainer
trainer = Trainer(
    model=model,  # Your loaded Llama model
    args=training_args,
    train_dataset=dataset["train"],  # Your training dataset
    eval_dataset=dataset["validation"],  # Your validation dataset (if available)
)

# Train the model
trainer.train()

# Save the trained model
trainer.save_model("./trained_llama_model")

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("token-classification", model="dslim/bert-base-NER")
# Perform NER
ner_results = pipe(conversation)

# Print the results
for entity in ner_results:
    print(f"Entity: {entity['word']}, Label: {entity['entity']}, Confidence: {entity['score']:.4f}")
# Out:
# config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Entity: Alaska, Label: B-LOC, Confidence: 0.9997
# Entity: de, Label: B-MISC, Confidence: 0.9797
# Entity: Havilland, Label: I-MISC, Confidence: 0.9783
# Entity: D, Label: I-MISC, Confidence: 0.9908
# Entity: ##HC, Label: I-MISC, Confidence: 0.9855
# Entity: -, Label: I-MISC, Confidence: 0.7882
# Entity: 2, Label: I-MISC, Confidence: 0.9665
# Entity: Beaver, Label: B-MISC, Confidence: 0.7368
# Entity: de, Label: B-MISC, Confidence: 0.9824
# Entity: Havilland, Label: I-MISC, Confidence: 0.9814
# Entity: D, Label: I-MISC, Confidence: 0.9822
# Entity: ##HC, Label: I-MISC, Confidence: 0.9795
# Entity: -, Label: I-MISC, Confidence: 0.8404
# Entity: 3, Label: I-MISC, Confidence: 0.9645
# Entity: O, Label: B-MISC, Confidence: 0.4588
# Entity: ##tter, Label: I-MISC, Confidence: 0.4806
# Entity: Ke, Label: B-LOC, Confidence: 0.9991
# Entity: ##tch, Label: B-LOC, Confidence: 0.9839
# Entity: ##ika, Label: I-LOC, Confidence: 0.9948
# Entity: ##n, Label: I-LOC, Confidence: 0.9656
# Entity: Alaska, Label: B-LOC, Confidence: 0.9997
# Entity: D, Label: B-MISC, Confidence: 0.9346
# Entity: ##HC, Label: I-MISC, Confidence: 0.9027
# Entity: 2, Label: I-ORG, Confidence: 0.6934
# Entity: D, Label: B-MISC, Confidence: 0.9702
# Entity: ##HC, Label: I-MISC, Confidence: 0.9346
# Entity: 3, Label: I-MISC, Confidence: 0.6632
# Entity: D, Label: B-MISC, Confidence: 0.9936
# Entity: ##HC, Label: I-MISC, Confidence: 0.9586
# Entity: -, Label: I-MISC, Confidence: 0.6948
# Entity: 2, Label: I-MISC, Confidence: 0.9699
# Entity: D, Label: B-MISC, Confidence: 0.9907
# Entity: ##HC, Label: I-MISC, Confidence: 0.9634
# Entity: -, Label: I-MISC, Confidence: 0.7773
# Entity: 3, Label: I-MISC, Confidence: 0.9438
# Entity: D, Label: B-MISC, Confidence: 0.9947
# Entity: ##HC, Label: I-MISC, Confidence: 0.9618
# Entity: -, Label: I-MISC, Confidence: 0.7980
# Entity: 2, Label: I-MISC, Confidence: 0.9600
# Entity: Mountain, Label: B-ORG, Confidence: 0.9991
# Entity: Air, Label: I-ORG, Confidence: 0.9990
# Entity: Service, Label: I-ORG, Confidence: 0.9989
# Entity: LLC, Label: I-ORG, Confidence: 0.9985
# Entity: Ke, Label: B-LOC, Confidence: 0.9980
# Entity: ##tch, Label: I-LOC, Confidence: 0.9620
# Entity: ##ika, Label: I-LOC, Confidence: 0.9964
# Entity: ##n, Label: I-LOC, Confidence: 0.9813
# Entity: Alaska, Label: B-LOC, Confidence: 0.9997
# Entity: Title, Label: B-MISC, Confidence: 0.9949
# Entity: 14, Label: I-MISC, Confidence: 0.9988
# Entity: Code, Label: I-MISC, Confidence: 0.9907
# Entity: of, Label: I-MISC, Confidence: 0.9985
# Entity: Federal, Label: I-MISC, Confidence: 0.9974
# Entity: Regulations, Label: I-MISC, Confidence: 0.9954
# Entity: CF, Label: B-MISC, Confidence: 0.5085
# Entity: Part, Label: B-MISC, Confidence: 0.8037
# Entity: 135, Label: I-MISC, Confidence: 0.9016
# Entity: D, Label: B-MISC, Confidence: 0.9908
# Entity: ##HC, Label: I-MISC, Confidence: 0.9356
# Entity: -, Label: I-MISC, Confidence: 0.5510
# Entity: 3, Label: I-MISC, Confidence: 0.8570
# Entity: Pan, Label: B-ORG, Confidence: 0.9982
# Entity: ##tech, Label: I-ORG, Confidence: 0.9980
# Entity: ##nic, Label: I-ORG, Confidence: 0.9982
# Entity: ##on, Label: I-ORG, Confidence: 0.9965
# Entity: Aviation, Label: I-ORG, Confidence: 0.9968
# Entity: L, Label: I-ORG, Confidence: 0.9846
# Entity: ##T, Label: I-ORG, Confidence: 0.9505
# Entity: ##D, Label: I-ORG, Confidence: 0.9620
# Entity: Mind, Label: B-LOC, Confidence: 0.9955
# Entity: ##en, Label: I-LOC, Confidence: 0.9428
# Entity: Nevada, Label: B-LOC, Confidence: 0.9996
# Entity: Venture, Label: B-ORG, Confidence: 0.9984
# Entity: Travel, Label: I-ORG, Confidence: 0.9981
# Entity: ,, Label: I-ORG, Confidence: 0.9976
# Entity: LLC, Label: I-ORG, Confidence: 0.9900
# Entity: d, Label: B-ORG, Confidence: 0.5269
# Entity: Ta, Label: B-ORG, Confidence: 0.8877
# Entity: ##qua, Label: I-ORG, Confidence: 0.5762
# Entity: ##n, Label: I-ORG, Confidence: 0.9646
# Entity: Air, Label: I-ORG, Confidence: 0.9915
# Entity: Ke, Label: B-LOC, Confidence: 0.9960
# Entity: ##tch, Label: I-LOC, Confidence: 0.7255
# Entity: ##ika, Label: I-LOC, Confidence: 0.9907
# Entity: ##n, Label: I-LOC, Confidence: 0.9921
# Entity: Alaska, Label: B-LOC, Confidence: 0.9997
# Entity: Part, Label: B-MISC, Confidence: 0.7801
# Entity: 135, Label: I-MISC, Confidence: 0.9041
# Entity: Ke, Label: B-LOC, Confidence: 0.8361
# Entity: ##tch, Label: B-LOC, Confidence: 0.9524
# Entity: ##ika, Label: I-LOC, Confidence: 0.9733
# Entity: ##n, Label: I-LOC, Confidence: 0.9225
# Entity: Harbor, Label: I-LOC, Confidence: 0.9896
# Entity: Sea, Label: I-LOC, Confidence: 0.9525
# Entity: ##plane, Label: I-ORG, Confidence: 0.5612
# Entity: Base, Label: I-LOC, Confidence: 0.8732
# Entity: Ke, Label: B-LOC, Confidence: 0.9991
# Entity: ##tch, Label: I-LOC, Confidence: 0.9718
# Entity: ##ika, Label: I-LOC, Confidence: 0.9973
# Entity: ##n, Label: I-LOC, Confidence: 0.9975
# Entity: Alaska, Label: B-LOC, Confidence: 0.9997
# Entity: AD, Label: B-MISC, Confidence: 0.7532
# Entity: B, Label: I-MISC, Confidence: 0.5585
# Entity: D, Label: B-MISC, Confidence: 0.9172
# Entity: ##HC, Label: I-MISC, Confidence: 0.9190
# Entity: 3, Label: I-MISC, Confidence: 0.7772
# Entity: D, Label: B-MISC, Confidence: 0.9932
# Entity: ##HC, Label: I-MISC, Confidence: 0.9555
# Entity: -, Label: I-MISC, Confidence: 0.8477
# Entity: 2, Label: I-MISC, Confidence: 0.9601
# Entity: D, Label: B-ORG, Confidence: 0.9938
# Entity: ##HC, Label: I-ORG, Confidence: 0.7490

# %%
ner_results
# Out:
# [{'entity': 'B-LOC',
#   'score': 0.99974316,
#   'index': 10,
#   'word': 'Alaska',
#   'start': 29,
#   'end': 35},
#  {'entity': 'B-MISC',
#   'score': 0.9797102,
#   'index': 18,
#   'word': 'de',
#   'start': 68,
#   'end': 70},
#  {'entity': 'I-MISC',
#   'score': 0.978272,
#   'index': 19,
#   'word': 'Havilland',
#   'start': 71,
#   'end': 80},
#  {'entity': 'I-MISC',
#   'score': 0.990807,
#   'index': 20,
#   'word': 'D',
#   'start': 81,
#   'end': 82},
#  {'entity': 'I-MISC',
#   'score': 0.9854892,
#   'index': 21,
#   'word': '##HC',
#   'start': 82,
#   'end': 84},
#  {'entity': 'I-MISC',
#   'score': 0.7882364,
#   'index': 22,
#   'word': '-',
#   'start': 84,
#   'end': 85},
#  {'entity': 'I-MISC',
#   'score': 0.966472,
#   'index': 23,
#   'word': '2',
#   'start': 85,
#   'end': 86},
#  {'entity': 'B-MISC',
#   'score': 0.7367695,
#   'index': 25,
#   'word': 'Beaver',
#   'start': 88,
#   'end': 94},
#  {'entity': 'B-MISC',
#   'score': 0.9824066,
#   'index': 41,
#   'word': 'de',
#   'start': 135,
#   'end': 137},
#  {'entity': 'I-MISC',
#   'score': 0.98143506,
#   'index': 42,
#   'word': 'Havilland',
#   'start': 138,
#   'end': 147},
#  {'entity': 'I-MISC',
#   'score': 0.9822336,
#   'index': 43,
#   'word': 'D',
#   'start': 148,
#   'end': 149},
#  {'entity': 'I-MISC',
#   'score': 0.9794938,
#   'index': 44,
#   'word': '##HC',
#   'start': 149,
#   'end': 151},
#  {'entity': 'I-MISC',
#   'score': 0.8403798,
#   'index': 45,
#   'word': '-',
#   'start': 151,
#   'end': 152},
#  {'entity': 'I-MISC',
#   'score': 0.96454984,
#   'index': 46,
#   'word': '3',
#   'start': 152,
#   'end': 153},
#  {'entity': 'B-MISC',
#   'score': 0.45875663,
#   'index': 48,
#   'word': 'O',
#   'start': 155,
#   'end': 156},
#  {'entity': 'I-MISC',
#   'score': 0.48058388,
#   'index': 49,
#   'word': '##tter',
#   'start': 156,
#   'end': 160},
#  {'entity': 'B-LOC',
#   'score': 0.99911517,
#   'index': 68,
#   'word': 'Ke',
#   'start': 226,
#   'end': 228},
#  {'entity': 'B-LOC',
#   'score': 0.9838937,
#   'index': 69,
#   'word': '##tch',
#   'start': 228,
#   'end': 231},
#  {'entity': 'I-LOC',
#   'score': 0.99482733,
#   'index': 70,
#   'word': '##ika',
#   'start': 231,
#   'end': 234},
#  {'entity': 'I-LOC',
#   'score': 0.9655858,
#   'index': 71,
#   'word': '##n',
#   'start': 234,
#   'end': 235},
#  {'entity': 'B-LOC',
#   'score': 0.999731,
#   'index': 73,
#   'word': 'Alaska',
#   'start': 237,
#   'end': 243},
#  {'entity': 'B-MISC',
#   'score': 0.93458354,
#   'index': 76,
#   'word': 'D',
#   'start': 249,
#   'end': 250},
#  {'entity': 'I-MISC',
#   'score': 0.9026937,
#   'index': 77,
#   'word': '##HC',
#   'start': 250,
#   'end': 252},
#  {'entity': 'I-ORG',
#   'score': 0.69339913,
#   'index': 79,
#   'word': '2',
#   'start': 253,
#   'end': 254},
#  {'entity': 'B-MISC',
#   'score': 0.97016865,
#   'index': 89,
#   'word': 'D',
#   'start': 311,
#   'end': 312},
#  {'entity': 'I-MISC',
#   'score': 0.9346202,
#   'index': 90,
#   'word': '##HC',
#   'start': 312,
#   'end': 314},
#  {'entity': 'I-MISC',
#   'score': 0.6632099,
#   'index': 92,
#   'word': '3',
#   'start': 315,
#   'end': 316},
#  {'entity': 'B-MISC',
#   'score': 0.9935823,
#   'index': 112,
#   'word': 'D',
#   'start': 441,
#   'end': 442},
#  {'entity': 'I-MISC',
#   'score': 0.95862114,
#   'index': 113,
#   'word': '##HC',
#   'start': 442,
#   'end': 444},
#  {'entity': 'I-MISC',
#   'score': 0.6948002,
#   'index': 114,
#   'word': '-',
#   'start': 444,
#   'end': 445},
#  {'entity': 'I-MISC',
#   'score': 0.9698704,
#   'index': 115,
#   'word': '2',
#   'start': 445,
#   'end': 446},
#  {'entity': 'B-MISC',
#   'score': 0.9907323,
#   'index': 120,
#   'word': 'D',
#   'start': 469,
#   'end': 470},
#  {'entity': 'I-MISC',
#   'score': 0.96336335,
#   'index': 121,
#   'word': '##HC',
#   'start': 470,
#   'end': 472},
#  {'entity': 'I-MISC',
#   'score': 0.77732676,
#   'index': 122,
#   'word': '-',
#   'start': 472,
#   'end': 473},
#  {'entity': 'I-MISC',
#   'score': 0.9438253,
#   'index': 123,
#   'word': '3',
#   'start': 473,
#   'end': 474},
#  {'entity': 'B-MISC',
#   'score': 0.9946743,
#   'index': 129,
#   'word': 'D',
#   'start': 509,
#   'end': 510},
#  {'entity': 'I-MISC',
#   'score': 0.96181905,
#   'index': 130,
#   'word': '##HC',
#   'start': 510,
#   'end': 512},
#  {'entity': 'I-MISC',
#   'score': 0.79802704,
#   'index': 131,
#   'word': '-',
#   'start': 512,
#   'end': 513},
#  {'entity': 'I-MISC',
#   'score': 0.96004343,
#   'index': 132,
#   'word': '2',
#   'start': 513,
#   'end': 514},
#  {'entity': 'B-ORG',
#   'score': 0.99905545,
#   'index': 139,
#   'word': 'Mountain',
#   'start': 549,
#   'end': 557},
#  {'entity': 'I-ORG',
#   'score': 0.9989974,
#   'index': 140,
#   'word': 'Air',
#   'start': 558,
#   'end': 561},
#  {'entity': 'I-ORG',
#   'score': 0.9988501,
#   'index': 141,
#   'word': 'Service',
#   'start': 562,
#   'end': 569},
#  {'entity': 'I-ORG',
#   'score': 0.998486,
#   'index': 142,
#   'word': 'LLC',
#   'start': 570,
#   'end': 573},
#  {'entity': 'B-LOC',
#   'score': 0.9980252,
#   'index': 144,
#   'word': 'Ke',
#   'start': 575,
#   'end': 577},
#  {'entity': 'I-LOC',
#   'score': 0.96203816,
#   'index': 145,
#   'word': '##tch',
#   'start': 577,
#   'end': 580},
#  {'entity': 'I-LOC',
#   'score': 0.99636394,
#   'index': 146,
#   'word': '##ika',
#   'start': 580,
#   'end': 583},
#  {'entity': 'I-LOC',
#   'score': 0.981344,
#   'index': 147,
#   'word': '##n',
#   'start': 583,
#   'end': 584},
#  {'entity': 'B-LOC',
#   'score': 0.99969554,
#   'index': 149,
#   'word': 'Alaska',
#   'start': 586,
#   'end': 592},
#  {'entity': 'B-MISC',
#   'score': 0.994935,
#   'index': 155,
#   'word': 'Title',
#   'start': 618,
#   'end': 623},
#  {'entity': 'I-MISC',
#   'score': 0.99877733,
#   'index': 156,
#   'word': '14',
#   'start': 624,
#   'end': 626},
#  {'entity': 'I-MISC',
#   'score': 0.9907274,
#   'index': 157,
#   'word': 'Code',
#   'start': 627,
#   'end': 631},
#  {'entity': 'I-MISC',
#   'score': 0.9985453,
#   'index': 158,
#   'word': 'of',
#   'start': 632,
#   'end': 634},
#  {'entity': 'I-MISC',
#   'score': 0.99736315,
#   'index': 159,
#   'word': 'Federal',
#   'start': 635,
#   'end': 642},
#  {'entity': 'I-MISC',
#   'score': 0.9953898,
#   'index': 160,
#   'word': 'Regulations',
#   'start': 643,
#   'end': 654},
#  {'entity': 'B-MISC',
#   'score': 0.508482,
#   'index': 162,
#   'word': 'CF',
#   'start': 656,
#   'end': 658},
#  {'entity': 'B-MISC',
#   'score': 0.80374193,
#   'index': 165,
#   'word': 'Part',
#   'start': 661,
#   'end': 665},
#  {'entity': 'I-MISC',
#   'score': 0.90159667,
#   'index': 166,
#   'word': '135',
#   'start': 666,
#   'end': 669},
#  {'entity': 'B-MISC',
#   'score': 0.99077576,
#   'index': 178,
#   'word': 'D',
#   'start': 710,
#   'end': 711},
#  {'entity': 'I-MISC',
#   'score': 0.93558264,
#   'index': 179,
#   'word': '##HC',
#   'start': 711,
#   'end': 713},
#  {'entity': 'I-MISC',
#   'score': 0.5510367,
#   'index': 180,
#   'word': '-',
#   'start': 713,
#   'end': 714},
#  {'entity': 'I-MISC',
#   'score': 0.85701776,
#   'index': 181,
#   'word': '3',
#   'start': 714,
#   'end': 715},
#  {'entity': 'B-ORG',
#   'score': 0.9982108,
#   'index': 185,
#   'word': 'Pan',
#   'start': 734,
#   'end': 737},
#  {'entity': 'I-ORG',
#   'score': 0.9979716,
#   'index': 186,
#   'word': '##tech',
#   'start': 737,
#   'end': 741},
#  {'entity': 'I-ORG',
#   'score': 0.99824655,
#   'index': 187,
#   'word': '##nic',
#   'start': 741,
#   'end': 744},
#  {'entity': 'I-ORG',
#   'score': 0.99650323,
#   'index': 188,
#   'word': '##on',
#   'start': 744,
#   'end': 746},
#  {'entity': 'I-ORG',
#   'score': 0.9968119,
#   'index': 189,
#   'word': 'Aviation',
#   'start': 747,
#   'end': 755},
#  {'entity': 'I-ORG',
#   'score': 0.9846101,
#   'index': 190,
#   'word': 'L',
#   'start': 756,
#   'end': 757},
#  {'entity': 'I-ORG',
#   'score': 0.9504511,
#   'index': 191,
#   'word': '##T',
#   'start': 757,
#   'end': 758},
#  {'entity': 'I-ORG',
#   'score': 0.96202636,
#   'index': 192,
#   'word': '##D',
#   'start': 758,
#   'end': 759},
#  {'entity': 'B-LOC',
#   'score': 0.9954502,
#   'index': 194,
#   'word': 'Mind',
#   'start': 761,
#   'end': 765},
#  {'entity': 'I-LOC',
#   'score': 0.94278556,
#   'index': 195,
#   'word': '##en',
#   'start': 765,
#   'end': 767},
#  {'entity': 'B-LOC',
#   'score': 0.999613,
#   'index': 197,
#   'word': 'Nevada',
#   'start': 769,
#   'end': 775},
#  {'entity': 'B-ORG',
#   'score': 0.9984402,
#   'index': 202,
#   'word': 'Venture',
#   'start': 793,
#   'end': 800},
#  {'entity': 'I-ORG',
#   'score': 0.9980849,
#   'index': 203,
#   'word': 'Travel',
#   'start': 801,
#   'end': 807},
#  {'entity': 'I-ORG',
#   'score': 0.9976319,
#   'index': 204,
#   'word': ',',
#   'start': 807,
#   'end': 808},
#  {'entity': 'I-ORG',
#   'score': 0.989965,
#   'index': 205,
#   'word': 'LLC',
#   'start': 809,
#   'end': 812},
#  {'entity': 'B-ORG',
#   'score': 0.5269148,
#   'index': 207,
#   'word': 'd',
#   'start': 814,
#   'end': 815},
#  {'entity': 'B-ORG',
#   'score': 0.88770294,
#   'index': 209,
#   'word': 'Ta',
#   'start': 818,
#   'end': 820},
#  {'entity': 'I-ORG',
#   'score': 0.57617915,
#   'index': 210,
#   'word': '##qua',
#   'start': 820,
#   'end': 823},
#  {'entity': 'I-ORG',
#   'score': 0.9646163,
#   'index': 211,
#   'word': '##n',
#   'start': 823,
#   'end': 824},
#  {'entity': 'I-ORG',
#   'score': 0.9915399,
#   'index': 212,
#   'word': 'Air',
#   'start': 825,
#   'end': 828},
#  {'entity': 'B-LOC',
#   'score': 0.995996,
#   'index': 214,
#   'word': 'Ke',
#   'start': 830,
#   'end': 832},
#  {'entity': 'I-LOC',
#   'score': 0.725511,
#   'index': 215,
#   'word': '##tch',
#   'start': 832,
#   'end': 835},
#  {'entity': 'I-LOC',
#   'score': 0.9906826,
#   'index': 216,
#   'word': '##ika',
#   'start': 835,
#   'end': 838},
#  {'entity': 'I-LOC',
#   'score': 0.99213624,
#   'index': 217,
#   'word': '##n',
#   'start': 838,
#   'end': 839},
#  {'entity': 'B-LOC',
#   'score': 0.9996785,
#   'index': 219,
#   'word': 'Alaska',
#   'start': 841,
#   'end': 847},
#  {'entity': 'B-MISC',
#   'score': 0.78014815,
#   'index': 225,
#   'word': 'Part',
#   'start': 873,
#   'end': 877},
#  {'entity': 'I-MISC',
#   'score': 0.9040733,
#   'index': 226,
#   'word': '135',
#   'start': 878,
#   'end': 881},
#  {'entity': 'B-LOC',
#   'score': 0.836149,
#   'index': 284,
#   'word': 'Ke',
#   'start': 1180,
#   'end': 1182},
#  {'entity': 'B-LOC',
#   'score': 0.9524051,
#   'index': 285,
#   'word': '##tch',
#   'start': 1182,
#   'end': 1185},
#  {'entity': 'I-LOC',
#   'score': 0.9733204,
#   'index': 286,
#   'word': '##ika',
#   'start': 1185,
#   'end': 1188},
#  {'entity': 'I-LOC',
#   'score': 0.92249423,
#   'index': 287,
#   'word': '##n',
#   'start': 1188,
#   'end': 1189},
#  {'entity': 'I-LOC',
#   'score': 0.9895627,
#   'index': 288,
#   'word': 'Harbor',
#   'start': 1190,
#   'end': 1196},
#  {'entity': 'I-LOC',
#   'score': 0.9524922,
#   'index': 289,
#   'word': 'Sea',
#   'start': 1197,
#   'end': 1200},
#  {'entity': 'I-ORG',
#   'score': 0.56124246,
#   'index': 290,
#   'word': '##plane',
#   'start': 1200,
#   'end': 1205},
#  {'entity': 'I-LOC',
#   'score': 0.873219,
#   'index': 291,
#   'word': 'Base',
#   'start': 1206,
#   'end': 1210},
#  {'entity': 'B-LOC',
#   'score': 0.9991043,
#   'index': 297,
#   'word': 'Ke',
#   'start': 1218,
#   'end': 1220},
#  {'entity': 'I-LOC',
#   'score': 0.9718122,
#   'index': 298,
#   'word': '##tch',
#   'start': 1220,
#   'end': 1223},
#  {'entity': 'I-LOC',
#   'score': 0.9972894,
#   'index': 299,
#   'word': '##ika',
#   'start': 1223,
#   'end': 1226},
#  {'entity': 'I-LOC',
#   'score': 0.9975172,
#   'index': 300,
#   'word': '##n',
#   'start': 1226,
#   'end': 1227},
#  {'entity': 'B-LOC',
#   'score': 0.9996927,
#   'index': 302,
#   'word': 'Alaska',
#   'start': 1229,
#   'end': 1235},
#  {'entity': 'B-MISC',
#   'score': 0.7532444,
#   'index': 315,
#   'word': 'AD',
#   'start': 1309,
#   'end': 1311},
#  {'entity': 'I-MISC',
#   'score': 0.558477,
#   'index': 318,
#   'word': 'B',
#   'start': 1313,
#   'end': 1314},
#  {'entity': 'B-MISC',
#   'score': 0.91715384,
#   'index': 336,
#   'word': 'D',
#   'start': 1380,
#   'end': 1381},
#  {'entity': 'I-MISC',
#   'score': 0.91899407,
#   'index': 337,
#   'word': '##HC',
#   'start': 1381,
#   'end': 1383},
#  {'entity': 'I-MISC',
#   'score': 0.77720016,
#   'index': 339,
#   'word': '3',
#   'start': 1384,
#   'end': 1385},
#  {'entity': 'B-MISC',
#   'score': 0.9932482,
#   'index': 365,
#   'word': 'D',
#   'start': 1463,
#   'end': 1464},
#  {'entity': 'I-MISC',
#   'score': 0.9555021,
#   'index': 366,
#   'word': '##HC',
#   'start': 1464,
#   'end': 1466},
#  {'entity': 'I-MISC',
#   'score': 0.8476854,
#   'index': 367,
#   'word': '-',
#   'start': 1466,
#   'end': 1467},
#  {'entity': 'I-MISC',
#   'score': 0.9600537,
#   'index': 368,
#   'word': '2',
#   'start': 1467,
#   'end': 1468},
#  {'entity': 'B-ORG',
#   'score': 0.99383634,
#   'index': 381,
#   'word': 'D',
#   'start': 1510,
#   'end': 1511},
#  {'entity': 'I-ORG',
#   'score': 0.7489955,
#   'index': 382,
#   'word': '##HC',
#   'start': 1511,
#   'end': 1513}]

# %%
from transformers import pipeline

# Load a pre-trained NER pipeline
ner_pipeline = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english")

# Example text to perform NER on
text = "Hugging Face Inc. is a company based in New York. Their CEO is Clem Delangue."

# Perform NER
ner_results = ner_pipeline(conversation)

# Print the results
for entity in ner_results:
    print(f"Entity: {entity['word']}, Label: {entity['entity']}, Confidence: {entity['score']:.4f}")
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Entity: Alaska, Label: I-LOC, Confidence: 0.9960
# Entity: de, Label: I-MISC, Confidence: 0.7556
# Entity: Havilland, Label: I-ORG, Confidence: 0.7663
# Entity: D, Label: I-MISC, Confidence: 0.9774
# Entity: ##HC, Label: I-MISC, Confidence: 0.9263
# Entity: -, Label: I-MISC, Confidence: 0.7970
# Entity: 2, Label: I-MISC, Confidence: 0.9734
# Entity: Beaver, Label: I-MISC, Confidence: 0.8939
# Entity: ##D, Label: I-ORG, Confidence: 0.5629
# Entity: de, Label: I-MISC, Confidence: 0.7760
# Entity: Havilland, Label: I-MISC, Confidence: 0.7946
# Entity: D, Label: I-MISC, Confidence: 0.9712
# Entity: ##HC, Label: I-MISC, Confidence: 0.9246
# Entity: -, Label: I-MISC, Confidence: 0.8028
# Entity: 3, Label: I-MISC, Confidence: 0.9678
# Entity: O, Label: I-MISC, Confidence: 0.9277
# Entity: ##tter, Label: I-MISC, Confidence: 0.9478
# Entity: ##PA, Label: I-ORG, Confidence: 0.5435
# Entity: Ke, Label: I-LOC, Confidence: 0.9986
# Entity: ##tch, Label: I-LOC, Confidence: 0.9867
# Entity: ##ika, Label: I-LOC, Confidence: 0.9809
# Entity: ##n, Label: I-LOC, Confidence: 0.9984
# Entity: Alaska, Label: I-LOC, Confidence: 0.9988
# Entity: D, Label: I-MISC, Confidence: 0.9535
# Entity: ##HC, Label: I-MISC, Confidence: 0.9191
# Entity: -, Label: I-MISC, Confidence: 0.7234
# Entity: 2, Label: I-MISC, Confidence: 0.9742
# Entity: D, Label: I-MISC, Confidence: 0.9520
# Entity: ##HC, Label: I-MISC, Confidence: 0.8921
# Entity: -, Label: I-MISC, Confidence: 0.6162
# Entity: 3, Label: I-MISC, Confidence: 0.9049
# Entity: D, Label: I-MISC, Confidence: 0.9389
# Entity: ##HC, Label: I-MISC, Confidence: 0.8922
# Entity: -, Label: I-MISC, Confidence: 0.5848
# Entity: 2, Label: I-MISC, Confidence: 0.9612
# Entity: D, Label: I-MISC, Confidence: 0.9165
# Entity: ##HC, Label: I-MISC, Confidence: 0.8458
# Entity: 3, Label: I-MISC, Confidence: 0.8326
# Entity: D, Label: I-MISC, Confidence: 0.9437
# Entity: ##HC, Label: I-MISC, Confidence: 0.9180
# Entity: -, Label: I-MISC, Confidence: 0.7176
# Entity: 2, Label: I-MISC, Confidence: 0.9750
# Entity: Mountain, Label: I-ORG, Confidence: 0.9992
# Entity: Air, Label: I-ORG, Confidence: 0.9993
# Entity: Service, Label: I-ORG, Confidence: 0.9993
# Entity: LLC, Label: I-ORG, Confidence: 0.9993
# Entity: Ke, Label: I-LOC, Confidence: 0.9913
# Entity: ##tch, Label: I-LOC, Confidence: 0.9674
# Entity: ##ika, Label: I-LOC, Confidence: 0.8842
# Entity: ##n, Label: I-LOC, Confidence: 0.9938
# Entity: Alaska, Label: I-LOC, Confidence: 0.9989
# Entity: Title, Label: I-MISC, Confidence: 0.9903
# Entity: 14, Label: I-MISC, Confidence: 0.9890
# Entity: Code, Label: I-MISC, Confidence: 0.9969
# Entity: of, Label: I-MISC, Confidence: 0.9890
# Entity: Federal, Label: I-MISC, Confidence: 0.9928
# Entity: Regulations, Label: I-MISC, Confidence: 0.9970
# Entity: CF, Label: I-MISC, Confidence: 0.9811
# Entity: ##R, Label: I-MISC, Confidence: 0.9936
# Entity: Part, Label: I-MISC, Confidence: 0.9514
# Entity: 135, Label: I-MISC, Confidence: 0.9239
# Entity: D, Label: I-MISC, Confidence: 0.9459
# Entity: ##HC, Label: I-MISC, Confidence: 0.9029
# Entity: -, Label: I-MISC, Confidence: 0.6976
# Entity: 3, Label: I-MISC, Confidence: 0.9535
# Entity: Pan, Label: I-ORG, Confidence: 0.9996
# Entity: ##tech, Label: I-ORG, Confidence: 0.9985
# Entity: ##nic, Label: I-ORG, Confidence: 0.9805
# Entity: ##on, Label: I-ORG, Confidence: 0.9989
# Entity: Aviation, Label: I-ORG, Confidence: 0.9988
# Entity: L, Label: I-ORG, Confidence: 0.9812
# Entity: ##T, Label: I-ORG, Confidence: 0.9285
# Entity: ##D, Label: I-ORG, Confidence: 0.8412
# Entity: Mind, Label: I-LOC, Confidence: 0.9881
# Entity: ##en, Label: I-LOC, Confidence: 0.9933
# Entity: Nevada, Label: I-LOC, Confidence: 0.9986
# Entity: Venture, Label: I-ORG, Confidence: 0.9995
# Entity: Travel, Label: I-ORG, Confidence: 0.9990
# Entity: ,, Label: I-ORG, Confidence: 0.9972
# Entity: LLC, Label: I-ORG, Confidence: 0.9993
# Entity: Ta, Label: I-ORG, Confidence: 0.9995
# Entity: ##qua, Label: I-ORG, Confidence: 0.9977
# Entity: ##n, Label: I-ORG, Confidence: 0.9990
# Entity: Air, Label: I-ORG, Confidence: 0.9992
# Entity: Ke, Label: I-LOC, Confidence: 0.9906
# Entity: ##tch, Label: I-LOC, Confidence: 0.9796
# Entity: ##ika, Label: I-LOC, Confidence: 0.9452
# Entity: ##n, Label: I-LOC, Confidence: 0.9964
# Entity: Alaska, Label: I-LOC, Confidence: 0.9988
# Entity: Part, Label: I-MISC, Confidence: 0.9655
# Entity: 135, Label: I-MISC, Confidence: 0.9053
# Entity: Ke, Label: I-LOC, Confidence: 0.9932
# Entity: ##tch, Label: I-LOC, Confidence: 0.9838
# Entity: ##ika, Label: I-LOC, Confidence: 0.9549
# Entity: ##n, Label: I-LOC, Confidence: 0.9955
# Entity: Harbor, Label: I-LOC, Confidence: 0.9912
# Entity: Sea, Label: I-LOC, Confidence: 0.9691
# Entity: ##plane, Label: I-LOC, Confidence: 0.5738
# Entity: Base, Label: I-LOC, Confidence: 0.7228
# Entity: 5, Label: I-LOC, Confidence: 0.4982
# Entity: Ke, Label: I-LOC, Confidence: 0.9985
# Entity: ##tch, Label: I-LOC, Confidence: 0.9828
# Entity: ##ika, Label: I-LOC, Confidence: 0.9639
# Entity: ##n, Label: I-LOC, Confidence: 0.9980
# Entity: Alaska, Label: I-LOC, Confidence: 0.9987
# Entity: AD, Label: I-MISC, Confidence: 0.5206
# Entity: D, Label: I-MISC, Confidence: 0.9186
# Entity: ##HC, Label: I-MISC, Confidence: 0.8852
# Entity: -, Label: I-MISC, Confidence: 0.6063
# Entity: 3, Label: I-MISC, Confidence: 0.9407
# Entity: D, Label: I-MISC, Confidence: 0.9348
# Entity: ##HC, Label: I-MISC, Confidence: 0.8795
# Entity: -, Label: I-MISC, Confidence: 0.5719
# Entity: 2, Label: I-MISC, Confidence: 0.9654
# Entity: D, Label: I-MISC, Confidence: 0.9359
# Entity: ##HC, Label: I-MISC, Confidence: 0.8153

# %%
from transformers import pipeline

# Load summarization pipeline with BART model
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

# Example text
text = """
Hugging Face Inc. is a company based in New York. They provide open-source tools that
allow people to use state-of-the-art machine learning models. Hugging Face has
popularized the transformer model architecture and made it accessible to developers
through their platform. In recent years, they have expanded their library to support
tasks such as summarization, translation, and text generation. Many companies and
researchers in the machine learning field rely on Hugging Face for their daily work.
"""
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Hugging Face Inc. is a company based in New York. They provide open-source tools that allow people to use state-of-the-art machine learning models. Many companies and researchers in the machine learning

# %%
# Summarize the text
text = conversation
summary = summarizer(text, max_length=50, min_length=25, do_sample=False)

# Print the summary
print(summary[0]['summary_text'])
# Out:
# On May 13, 2019, about 1221 Alaska daylight time, a de Havilland DHC-2 (Beaver) airplane, N952DB, and a float-equipped de Haviland D HC-3 (O

# %%
from transformers import pipeline

# Load summarization pipeline with Pegasus model
summarizer = pipeline("summarization", model="google/pegasus-cnn_dailymail")

# Summarize the text
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-cnn_dailymail and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# generation_config.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/88.0 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
text = """
On May 13, 2019, about 1221 Alaska daylight time, a float-equipped de Havilland DHC-2 (Beaver) airplane, N952DB, and a float-equipped de Havilland DHC-3 (Otter) airplane, N959PA, collided in midair about 8 miles northeast of Ketchikan, Alaska. The DHC-2 pilot and four passengers sustained fatal injuries. The DHC-3 pilot sustained minor injuries, nine passengers sustained serious injuries, and one passenger sustained fatal injuries. The DHC-2 was destroyed and the DHC-3 sustained substantial damage. The DHC-2 was registered to and operated by Mountain Air Service LLC, Ketchikan, Alaska, under the provisions of Title 14 Code of Federal Regulations (CFR) Part 135 as an on-demand sightseeing flight. The DHC-3 was registered to Pantechnicon Aviation LTD, Minden, Nevada, and operated by Venture Travel, LLC, dba Taquan Air, Ketchikan, Alaska, under the provisions of Part 135 as an on-demand sightseeing flight. Visual meteorological conditions prevailed in the area at the time of the accident.
According to information provided by the operators, both airplanes had been conducting sightseeing flights and were both converging on a scenic waterfall before returning to the Ketchikan Harbor Seaplane Base (5KE), Ketchikan, Alaska, when the accident occurred. Automatic dependent surveillance-broadcast (ADS-B) tracking data for both airplanes revealed that, at 1217:15, the DHC-3 was about level at 4,000 ft mean sea level (msl) on a track of 225°, and the DHC-2 was 4.2 nautical miles (nm) south of the DHC-3, climbing through 2,800 ft msl, on a track of 255°.1 About 1219, the DHC-3 started a descent from 4,000 ft, and the DHC-2 was at 3,175 ft and climbing. During the next 1 minute 21 seconds, the DHC-3 continued to descend on a track between 224° and 237°, and the DHC-2 leveled out at 3,350 ft on a track of about 255°. The airplanes collided at 1221:14 at an altitude of 3,350 ft, 7.4 nm northeast of 5KE.
"""

# %%
summary = summarizer(text, max_length=125, min_length=25, do_sample=True)

# Print the summary
print(summary[0]['summary_text'])
# Out:
# A float-equipped de Havilland DHC-2 (Beaver) and a float-equipped de Havilland DHC-3 (Otter) airplane collided in midair about 8 miles northeast of Ketchikan, Alaska .<n>The DHC-2 pilot and four passengers sustained fatal injuries .<n>The DHC-3 pilot sustained minor injuries, nine passengers sustained serious injuries, and one passenger sustained fatal injuries .
